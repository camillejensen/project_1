# %%
import pandas as pd
import requests
import numpy as np
from matplotlib import pyplot as plt

# %%
file= "Resources/project1_data.csv"
df = pd.read_csv(file)
df.head()
# Out:
#   IndicatorCode                                          Indicator ValueType  \
# 0     SDGAIRBOD  Ambient and household air pollution attributab...   numeric
# 1     SDGAIRBOD  Ambient and household air pollution attributab...   numeric
# 2     SDGAIRBOD  Ambient and household air pollution attributab...   numeric
# 3     SDGAIRBOD  Ambient and household air pollution attributab...   numeric
# 4     SDGAIRBOD  Ambient and household air pollution attributab...   numeric
#
#   ParentLocationCode ParentLocation Location type SpatialDimValueCode  \
# 0                AFR         Africa       Country                 COM
# 1                AFR         Africa       Country                 NER
# 2                AMR       Americas       Country                 BHS
# 3                AFR         Africa       Country                 COM
# 4                AFR         Africa       Country                 GMB
#
#   Location Period type  Period  ...  FactValueUoM FactValueNumericLowPrefix  \
# 0  Comoros        Year    2019  ...           NaN                       NaN
# 1    Niger        Year    2019  ...           NaN                       NaN
# 2  Bahamas        Year    2019  ...           NaN                       NaN
# 3  Comoros        Year    2019  ...           NaN                       NaN
# 4   Gambia        Year    2019  ...           NaN                       NaN
#
#   FactValueNumericLow FactValueNumericHighPrefix FactValueNumericHigh  \
# 0               0.000                        NaN                0.000
# 1               0.020                        NaN                0.027
# 2               0.000                        NaN                0.140
# 3               0.053                        NaN                0.076
# 4               0.058                        NaN                0.076
#
#                    Value FactValueTranslationID  FactComments  Language  \
# 0              0 [0 – 0]                    NaN           NaN        EN
# 1   0.024 [0.02 – 0.027]                    NaN           NaN        EN
# 2       0.046 [0 – 0.14]                    NaN           NaN        EN
# 3  0.065 [0.053 – 0.076]                    NaN           NaN        EN
# 4  0.068 [0.058 – 0.076]                    NaN           NaN        EN
#
#                DateModified
# 0  2022-08-26T05:00:00.000Z
# 1  2022-08-26T05:00:00.000Z
# 2  2022-08-26T05:00:00.000Z
# 3  2022-08-26T05:00:00.000Z
# 4  2022-08-26T05:00:00.000Z
#
# [5 rows x 34 columns]

# %%
new_df= df[df["IndicatorCode"]=="SDGAIRBODA"]
new_df.head()
# Out:
#      IndicatorCode                                          Indicator  \
# 3294    SDGAIRBODA  Ambient and household air pollution attributab...
# 3295    SDGAIRBODA  Ambient and household air pollution attributab...
# 3296    SDGAIRBODA  Ambient and household air pollution attributab...
# 3297    SDGAIRBODA  Ambient and household air pollution attributab...
# 3298    SDGAIRBODA  Ambient and household air pollution attributab...
#
#      ValueType ParentLocationCode ParentLocation Location type  \
# 3294   numeric                AFR         Africa       Country
# 3295   numeric                AMR       Americas       Country
# 3296   numeric                AFR         Africa       Country
# 3297   numeric                AMR       Americas       Country
# 3298   numeric                AMR       Americas       Country
#
#      SpatialDimValueCode             Location Period type  Period  ...  \
# 3294                 COM              Comoros        Year    2019  ...
# 3295                 BHS              Bahamas        Year    2019  ...
# 3296                 NER                Niger        Year    2019  ...
# 3297                 BHS              Bahamas        Year    2019  ...
# 3298                 ATG  Antigua and Barbuda        Year    2019  ...
#
#       FactValueUoM FactValueNumericLowPrefix FactValueNumericLow  \
# 3294           NaN                       NaN               0.000
# 3295           NaN                       NaN               0.000
# 3296           NaN                       NaN               0.036
# 3297           NaN                       NaN               0.000
# 3298           NaN                       NaN               0.025
#
#      FactValueNumericHighPrefix FactValueNumericHigh                  Value  \
# 3294                        NaN                0.000              0 [0 – 0]
# 3295                        NaN                0.130       0.042 [0 – 0.13]
# 3296                        NaN                0.047  0.042 [0.036 – 0.047]
# 3297                        NaN                0.240       0.079 [0 – 0.24]
# 3298                        NaN                0.180   0.084 [0.025 – 0.18]
#
#      FactValueTranslationID  FactComments  Language              DateModified
# 3294                    NaN           NaN        EN  2022-08-26T05:00:00.000Z
# 3295                    NaN           NaN        EN  2022-08-26T05:00:00.000Z
# 3296                    NaN           NaN        EN  2022-08-26T05:00:00.000Z
# 3297                    NaN           NaN        EN  2022-08-26T05:00:00.000Z
# 3298                    NaN           NaN        EN  2022-08-26T05:00:00.000Z
#
# [5 rows x 34 columns]

# %%
del new_df['IndicatorCode']
del new_df['Indicator']
del new_df['ValueType']
del new_df['ParentLocationCode']
del new_df['Location type']
del new_df['Period type']
del new_df['IsLatestYear']
del new_df['Dim1 type']
del new_df['Dim3 type']
del new_df['FactValueUoM']
del new_df['FactValueNumericLowPrefix']
del new_df['FactValueNumericHighPrefix']
del new_df['FactValueTranslationID']
del new_df['FactComments']
del new_df['Language']
del new_df['DateModified']
del new_df['Dim3']
del new_df['Dim3ValueCode']
del new_df['DataSourceDimValueCode']
del new_df['DataSource']
del new_df['FactValueNumericPrefix']
del new_df['Dim2 type']
del new_df['Dim2ValueCode']
del new_df['SpatialDimValueCode']
del new_df['Dim1ValueCode']
new_df.head()
# Out:
#      ParentLocation             Location  Period        Dim1  \
# 3294         Africa              Comoros    2019      Female
# 3295       Americas              Bahamas    2019      Female
# 3296         Africa                Niger    2019      Female
# 3297       Americas              Bahamas    2019  Both sexes
# 3298       Americas  Antigua and Barbuda    2019      Female
#
#                                  Dim2  FactValueNumeric  FactValueNumericLow  \
# 3294  Trachea, bronchus, lung cancers             0.000                0.000
# 3295  Trachea, bronchus, lung cancers             0.042                0.000
# 3296  Trachea, bronchus, lung cancers             0.042                0.036
# 3297  Trachea, bronchus, lung cancers             0.079                0.000
# 3298  Trachea, bronchus, lung cancers             0.084                0.025
#
#       FactValueNumericHigh                  Value
# 3294                 0.000              0 [0 – 0]
# 3295                 0.130       0.042 [0 – 0.13]
# 3296                 0.047  0.042 [0.036 – 0.047]
# 3297                 0.240       0.079 [0 – 0.24]
# 3298                 0.180   0.084 [0.025 – 0.18]

# %%
new_df=new_df.rename(columns= {'ParentLocation':'Continent', 'FactValueNumeric': 'Average Death Rate', 'Period': 'Year', 'Dim1':'Sex', 'FactValueNumericLow': 'Regional Low Deaths', 'FactValueNumericHigh': 'Regional High Deaths',
                      'Dim2': 'Cause of Death'})
new_df.head()
# Out:
#      Continent             Location  Year         Sex  \
# 3294    Africa              Comoros  2019      Female
# 3295  Americas              Bahamas  2019      Female
# 3296    Africa                Niger  2019      Female
# 3297  Americas              Bahamas  2019  Both sexes
# 3298  Americas  Antigua and Barbuda  2019      Female
#
#                        Cause of Death  Average Death Rate  \
# 3294  Trachea, bronchus, lung cancers               0.000
# 3295  Trachea, bronchus, lung cancers               0.042
# 3296  Trachea, bronchus, lung cancers               0.042
# 3297  Trachea, bronchus, lung cancers               0.079
# 3298  Trachea, bronchus, lung cancers               0.084
#
#       Regional Low Deaths  Regional High Deaths                  Value
# 3294                0.000                 0.000              0 [0 – 0]
# 3295                0.000                 0.130       0.042 [0 – 0.13]
# 3296                0.036                 0.047  0.042 [0.036 – 0.047]
# 3297                0.000                 0.240       0.079 [0 – 0.24]
# 3298                0.025                 0.180   0.084 [0.025 – 0.18]

# %%
#Which countries have the lowest total death rate for both sexes? Lowest Male? Lowest Female?
#Looking for average death rate total
total_df=new_df.loc[new_df['Cause of Death']=='Total']
total_df.head()
# Out:
#      Continent Location  Year         Sex Cause of Death  Average Death Rate  \
# 3938    Europe  Iceland  2019        Male          Total               10.00
# 3941    Europe   France  2019  Both sexes          Total               10.03
# 3948    Europe  Ireland  2019      Female          Total               10.11
# 3949    Europe    Spain  2019  Both sexes          Total               10.12
# 3951  Americas   Canada  2019        Male          Total               10.13
#
#       Regional Low Deaths  Regional High Deaths                 Value
# 3938                 5.53                 14.86     10 [5.53 – 14.86]
# 3941                 7.28                 13.01  10.03 [7.28 – 13.01]
# 3948                 6.76                 13.76  10.11 [6.76 – 13.76]
# 3949                 7.09                 13.31  10.12 [7.09 – 13.31]
# 3951                 6.16                 13.90   10.13 [6.16 – 13.9]

# %%
total_df_sorted= total_df.sort_values('Average Death Rate', ascending=True)
total_df_sorted
# Out:
#             Continent                  Location  Year     Sex Cause of Death  \
# 5741           Europe                   Finland  2019  Female          Total
# 6018         Americas                    Canada  2019  Female          Total
# 6028           Europe                    Norway  2019  Female          Total
# 6030           Europe                   Iceland  2019  Female          Total
# 6036           Europe                    Sweden  2019  Female          Total
# ...               ...                       ...   ...     ...            ...
# 5221           Africa                Mozambique  2019    Male          Total
# 5246  Western Pacific                  Kiribati  2019    Male          Total
# 5270  Western Pacific           Solomon Islands  2019    Male          Total
# 5330           Africa                   Lesotho  2019    Male          Total
# 5360           Africa  Central African Republic  2019    Male          Total
#
#       Average Death Rate  Regional Low Deaths  Regional High Deaths  \
# 5741                5.09                 2.81                  7.32
# 6018                6.31                 3.93                  8.74
# 6028                6.44                 4.07                  9.38
# 6030                6.48                 3.72                  9.91
# 6036                6.55                 4.02                  9.21
# ...                  ...                  ...                   ...
# 5221              308.10               257.90                360.90
# 5246              319.40               247.90                393.50
# 5270              324.70               254.50                391.10
# 5330              351.90               288.00                420.00
# 5360              364.90               302.70                434.20
#
#                       Value
# 5741     5.09 [2.81 – 7.32]
# 6018     6.31 [3.93 – 8.74]
# 6028     6.44 [4.07 – 9.38]
# 6030     6.48 [3.72 – 9.91]
# 6036     6.55 [4.02 – 9.21]
# ...                     ...
# 5221  308.1 [257.9 – 360.9]
# 5246  319.4 [247.9 – 393.5]
# 5270  324.7 [254.5 – 391.1]
# 5330      351.9 [288 – 420]
# 5360  364.9 [302.7 – 434.2]
#
# [549 rows x 9 columns]

# %%
both_sexes= total_df.loc[total_df['Sex']=='Both sexes']

# %%
both_sexes= both_sexes.sort_values('Average Death Rate', ascending= True)
both_sexes= both_sexes.reset_index(drop=True)

# %%
lowest_both= both_sexes.loc[0,:]
lowest_both
# Out:
# Continent                            Europe
# Location                            Finland
# Year                                   2019
# Sex                              Both sexes
# Cause of Death                        Total
# Average Death Rate                     7.44
# Regional Low Deaths                    4.05
# Regional High Deaths                  10.66
# Value                   7.44 [4.05 – 10.66]
# Name: 0, dtype: object

# %%
female= total_df.loc[total_df['Sex']=='Female']
female= female.sort_values('Average Death Rate', ascending= True)
female= female.reset_index(drop=True)
lowest_female= female.loc[0,:]
lowest_female
# Out:
# Continent                           Europe
# Location                           Finland
# Year                                  2019
# Sex                                 Female
# Cause of Death                       Total
# Average Death Rate                    5.09
# Regional Low Deaths                   2.81
# Regional High Deaths                  7.32
# Value                   5.09 [2.81 – 7.32]
# Name: 0, dtype: object

# %%
male= total_df.loc[total_df['Sex']=='Male']
male= male.sort_values('Average Death Rate', ascending= True)
male= male.reset_index(drop=True)
lowest_male= male.loc[0,:]
lowest_male
# Out:
# Continent                            Europe
# Location                             Norway
# Year                                   2019
# Sex                                    Male
# Cause of Death                        Total
# Average Death Rate                     9.42
# Regional Low Deaths                    5.79
# Regional High Deaths                  13.47
# Value                   9.42 [5.79 – 13.47]
# Name: 0, dtype: object

# %%
top_five= both_sexes.loc[0:4,:]
top_five
# Out:
#   Continent Location  Year         Sex Cause of Death  Average Death Rate  \
# 0    Europe  Finland  2019  Both sexes          Total                7.44
# 1    Europe   Norway  2019  Both sexes          Total                7.86
# 2    Europe   Sweden  2019  Both sexes          Total                8.08
# 3  Americas   Canada  2019  Both sexes          Total                8.11
# 4    Europe  Iceland  2019  Both sexes          Total                8.16
#
#    Regional Low Deaths  Regional High Deaths                Value
# 0                 4.05                 10.66  7.44 [4.05 – 10.66]
# 1                 4.88                 11.42  7.86 [4.88 – 11.42]
# 2                 4.93                 11.33  8.08 [4.93 – 11.33]
# 3                 4.97                 11.06  8.11 [4.97 – 11.06]
# 4                 4.67                 12.20   8.16 [4.67 – 12.2]

# %%
#Summary stats
mean= np.mean(top_five['Average Death Rate'])
print(f"The average death rate for both sexes of the 5 countries with the lowest death rate is {mean}")
# Out:
# The average death rate for both sexes of the 5 countries with the lowest death rate is 7.9300000000000015

# %%
#summary stats for all total(both)
mean_total= np.mean(both_sexes['Average Death Rate'])
mean_total
# Out:
# 100.76770491803279

# %%
median_total= np.median(both_sexes['Average Death Rate'])
median_total
# Out:
# 83.45

# %%
#Quartiles
death_rate= both_sexes['Average Death Rate']
quartiles = death_rate.quantile([.25,.5,.75])
lowerq = quartiles[0.25]
upperq = quartiles[0.75]
iqr = upperq-lowerq

print(f"The lower quartile of average death rate is: {lowerq}")
print(f"The upper quartile of average death rate is: {upperq}")
print(f"The interquartile range of average death rate is: {iqr}")
print(f"The the median of average death rate is: {quartiles[0.5]} ")

lower_bound = lowerq - (1.5*iqr)
upper_bound = upperq + (1.5*iqr)
print(f"Values below {lower_bound} could be outliers.")
print(f"Values above {upper_bound} could be outliers.")
# Out:
# The lower quartile of average death rate is: 31.665
# The upper quartile of average death rate is: 165.45
# The interquartile range of average death rate is: 133.785
# The the median of average death rate is: 83.45
# Values below -169.01250000000002 could be outliers.
# Values above 366.1275 could be outliers.

# %%
#Vizualizations
plt.figure(1)
female= [5.09, 6.44, 6.55, 6.31, 6.48]
male= [10.37, 9.42, 9.79, 10.13, 10.00]
both=[7.44, 7.86, 8.08, 8.11, 8.16]
index=['Finland', 'Norway', 'Sweden', 'Canada', 'Iceland']
fig_1_df= pd.DataFrame({'Female':female,
                    'Male': male, 'Both Sexes': both}, index=index)
fig_1_df

plot=fig_1_df.plot(kind='bar')
plt.title('Countries with the Lowest Average Death Rate by Both Sexes')
plt.xlabel('Country')
plt.ylabel('Average Death Rate')
plt.tight_layout()
plt.show()

# %%
#lowest female vs lowest male line
plt.figure(2)
x_axis= ['Finland', 'Norway', 'Sweden', 'Canada', 'Iceland']
f_y_axis= [5.09, 6.44, 6.55, 6.31, 6.48]
m_y_axis= [10.37, 9.42, 9.79, 10.13, 10.00]
female, = plt.plot(x_axis, f_y_axis, marker="o", color='blue', label="Female")
male, = plt.plot(x_axis, m_y_axis, marker="o", color="Orange", label="Male")
plt.legend(handles=[female, male], loc="best")
plt.title("Male vs Female Death Rates")
plt.xlabel("Country")
plt.ylabel("Average Death Rate")
plt.grid()
plt.show()

# %%
#########################################

# %%
total_df.head()
# Out:
#      Continent Location  Year         Sex Cause of Death  Average Death Rate  \
# 3938    Europe  Iceland  2019        Male          Total               10.00
# 3941    Europe   France  2019  Both sexes          Total               10.03
# 3948    Europe  Ireland  2019      Female          Total               10.11
# 3949    Europe    Spain  2019  Both sexes          Total               10.12
# 3951  Americas   Canada  2019        Male          Total               10.13
#
#       Regional Low Deaths  Regional High Deaths                 Value
# 3938                 5.53                 14.86     10 [5.53 – 14.86]
# 3941                 7.28                 13.01  10.03 [7.28 – 13.01]
# 3948                 6.76                 13.76  10.11 [6.76 – 13.76]
# 3949                 7.09                 13.31  10.12 [7.09 – 13.31]
# 3951                 6.16                 13.90   10.13 [6.16 – 13.9]

# %%
sorted_df2= total_df.sort_values('Location', ascending=True)
sorted_df2
# Out:
#                   Continent     Location  Year         Sex Cause of Death  \
# 4983  Eastern Mediterranean  Afghanistan  2019  Both sexes          Total
# 4981  Eastern Mediterranean  Afghanistan  2019      Female          Total
# 4982  Eastern Mediterranean  Afghanistan  2019        Male          Total
# 6558                 Europe      Albania  2019  Both sexes          Total
# 6564                 Europe      Albania  2019      Female          Total
# ...                     ...          ...   ...         ...            ...
# 4828                 Africa       Zambia  2019        Male          Total
# 4461                 Africa       Zambia  2019  Both sexes          Total
# 4407                 Africa     Zimbabwe  2019      Female          Total
# 4511                 Africa     Zimbabwe  2019  Both sexes          Total
# 4861                 Africa     Zimbabwe  2019        Male          Total
#
#       Average Death Rate  Regional Low Deaths  Regional High Deaths  \
# 4983              265.70               218.50                 313.9
# 4981              265.00               217.10                 313.4
# 4982              265.20               219.60                 313.0
# 6558               92.48                61.54                 126.1
# 6564               94.19                62.22                 129.0
# ...                  ...                  ...                   ...
# 4828              217.90               182.30                 256.7
# 4461              174.00               144.90                 205.4
# 4407              164.20               139.00                 191.1
# 4511              189.60               160.90                 220.4
# 4861              225.10               191.40                 261.9
#
#                       Value
# 4983  265.7 [218.5 – 313.9]
# 4981    265 [217.1 – 313.4]
# 4982    265.2 [219.6 – 313]
# 6558  92.48 [61.54 – 126.1]
# 6564    94.19 [62.22 – 129]
# ...                     ...
# 4828  217.9 [182.3 – 256.7]
# 4461    174 [144.9 – 205.4]
# 4407    164.2 [139 – 191.1]
# 4511  189.6 [160.9 – 220.4]
# 4861  225.1 [191.4 – 261.9]
#
# [549 rows x 9 columns]

# %%
female_high= sorted_df2.loc[sorted_df2['Sex']=='Female']
female_high= female_high.sort_values('Average Death Rate', ascending= False)
female_high= female_high.reset_index(drop=True)
female_high.head()
# Out:
#                Continent                  Location  Year     Sex  \
# 0  Eastern Mediterranean               Afghanistan  2019  Female
# 1                 Africa  Central African Republic  2019  Female
# 2                 Africa                   Lesotho  2019  Female
# 3        Western Pacific           Solomon Islands  2019  Female
# 4                 Africa              Sierra Leone  2019  Female
#
#   Cause of Death  Average Death Rate  Regional Low Deaths  \
# 0          Total               265.0                217.1
# 1          Total               257.8                215.5
# 2          Total               242.2                196.6
# 3          Total               238.6                189.8
# 4          Total               235.1                204.9
#
#    Regional High Deaths                  Value
# 0                 313.4    265 [217.1 – 313.4]
# 1                 306.5  257.8 [215.5 – 306.5]
# 2                 290.6  242.2 [196.6 – 290.6]
# 3                 286.4  238.6 [189.8 – 286.4]
# 4                 266.0    235.1 [204.9 – 266]

# %%
highest_female= female_high.loc[0,:]
highest_female
# Out:
# Continent               Eastern Mediterranean
# Location                          Afghanistan
# Year                                     2019
# Sex                                    Female
# Cause of Death                          Total
# Average Death Rate                        265
# Regional Low Deaths                     217.1
# Regional High Deaths                    313.4
# Value                     265 [217.1 – 313.4]
# Name: 0, dtype: object

# %%
male_high= total_df.loc[total_df['Sex']=='Male']
male_high= male_high.sort_values('Average Death Rate', ascending= False)
male_high= male_high.reset_index(drop=True)
male_high.head()
# Out:
#          Continent                  Location  Year   Sex Cause of Death  \
# 0           Africa  Central African Republic  2019  Male          Total
# 1           Africa                   Lesotho  2019  Male          Total
# 2  Western Pacific           Solomon Islands  2019  Male          Total
# 3  Western Pacific                  Kiribati  2019  Male          Total
# 4           Africa                Mozambique  2019  Male          Total
#
#    Average Death Rate  Regional Low Deaths  Regional High Deaths  \
# 0               364.9                302.7                 434.2
# 1               351.9                288.0                 420.0
# 2               324.7                254.5                 391.1
# 3               319.4                247.9                 393.5
# 4               308.1                257.9                 360.9
#
#                    Value
# 0  364.9 [302.7 – 434.2]
# 1      351.9 [288 – 420]
# 2  324.7 [254.5 – 391.1]
# 3  319.4 [247.9 – 393.5]
# 4  308.1 [257.9 – 360.9]

# %%
highest_male= male_high.loc[0,:]
highest_male
# Out:
# Continent                                 Africa
# Location                Central African Republic
# Year                                        2019
# Sex                                         Male
# Cause of Death                             Total
# Average Death Rate                         364.9
# Regional Low Deaths                        302.7
# Regional High Deaths                       434.2
# Value                      364.9 [302.7 – 434.2]
# Name: 0, dtype: object

# %%
both_sexes= total_df.loc[total_df['Sex']=='Both sexes']
both_sexes= both_sexes.sort_values('Average Death Rate', ascending= False)
both_sexes= both_sexes.reset_index(drop=True)


both_high= both_sexes.loc[0:4,:]

both_high
# Out:
#                Continent                  Location  Year         Sex  \
# 0                 Africa  Central African Republic  2019  Both sexes
# 1                 Africa                   Lesotho  2019  Both sexes
# 2        Western Pacific           Solomon Islands  2019  Both sexes
# 3  Eastern Mediterranean               Afghanistan  2019  Both sexes
# 4        Western Pacific                   Vanuatu  2019  Both sexes
#
#   Cause of Death  Average Death Rate  Regional Low Deaths  \
# 0          Total               305.1                254.1
# 1          Total               288.3                235.1
# 2          Total               281.2                221.5
# 3          Total               265.7                218.5
# 4          Total               259.9                203.4
#
#    Regional High Deaths                  Value
# 0                 362.4  305.1 [254.1 – 362.4]
# 1                 345.0    288.3 [235.1 – 345]
# 2                 338.3  281.2 [221.5 – 338.3]
# 3                 313.9  265.7 [218.5 – 313.9]
# 4                 316.7  259.9 [203.4 – 316.7]

# %%
mean_high= np.mean(both_high['Average Death Rate'])
print(f"The average death rate for both sexes of the 5 countries with the highest death rate is {mean_high}")
# Out:
# The average death rate for both sexes of the 5 countries with the highest death rate is 280.0400000000001

# %%
female_graph= [265.0, 257.8, 242.2, 238.6, 235.1]
male_fg=[265.2, 364.9, 351.9, 324.7, 243.4]
both_fg= [265.7,305.1, 288.3,  281.2, 239.0 ]

index_f=['Afghanistan', 'Central African Republic', 'Lesotho', 'Solomon Islands', 'Sierra Leone']

female_bar_df= pd.DataFrame({'Female':female_graph, 'Male': male_fg, 'Both Sexes': both_fg}, index=index_f)

female_bar_df.plot(kind="bar",)

plt.title('Countries with the Highest Average Female Death Rate')
plt.xlabel('Country')
plt.ylabel('Average Death Rate')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
male_graph= [364.9, 351.9, 324.7, 319.4, 308.1]

female_mg=[257.8, 242.2, 238.6, 191.3, 175.2]
both_mg= [305.1, 288.3, 281.2, 246.6, 228.4]



index_m=['Central African Republic', 'Lesotho', 'Solomon Islands', 'Kiribati', 'Mozambique']

male_bar_df= pd.DataFrame({'Male':male_graph,'Female':female_mg,'Both Sexes': both_mg }, index=index_m)
male_bar_df.plot(kind="bar")


plt.title('Countries with the Highest Average Male Death Rate')
plt.xlabel('Country')
plt.ylabel('Average Death Rate')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
both_graph=[305.1, 288.3, 281.2, 265.7, 259.9]

male_bg= [364.9, 351.9, 324.7, 265.2, 301.8]

female_bg=[257.8, 242.2, 238.6, 265.0, 216.3]

index_b=['Central African Republic', 'Lesotho', 'Solomon Islands', 'Afghanistan', 'Vanuatu']


both_bar_df= pd.DataFrame({'Both Sexes': both_graph, 'Male':male_bg,'Female':female_bg}, index=index_b)



both_bar_df.plot(kind="bar",)

plt.title('Countries with the Highest Average Death Rate For both sexes')
plt.xlabel('Country')
plt.ylabel('Average Death Rate')
plt.xticks(rotation=45)
plt.legend(loc='best')
plt.tight_layout()
plt.show()

# %%
#############################
