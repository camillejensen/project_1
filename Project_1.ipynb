# %%
import pandas as pd
import requests
import json

# %%
file= "Resources/project1_data.csv"
df = pd.read_csv(file)
df.head()
# Out:
#   IndicatorCode                                          Indicator ValueType  \
# 0     SDGAIRBOD  Ambient and household air pollution attributab...   numeric
# 1     SDGAIRBOD  Ambient and household air pollution attributab...   numeric
# 2     SDGAIRBOD  Ambient and household air pollution attributab...   numeric
# 3     SDGAIRBOD  Ambient and household air pollution attributab...   numeric
# 4     SDGAIRBOD  Ambient and household air pollution attributab...   numeric
#
#   ParentLocationCode ParentLocation Location type SpatialDimValueCode  \
# 0                AFR         Africa       Country                 COM
# 1                AFR         Africa       Country                 NER
# 2                AMR       Americas       Country                 BHS
# 3                AFR         Africa       Country                 COM
# 4                AFR         Africa       Country                 GMB
#
#   Location Period type  Period  ...  FactValueUoM FactValueNumericLowPrefix  \
# ...

# %%
new_df= df[df["IndicatorCode"]=="SDGAIRBODA"]
new_df.head()
# Out:
#      IndicatorCode                                          Indicator  \
# 3294    SDGAIRBODA  Ambient and household air pollution attributab...
# 3295    SDGAIRBODA  Ambient and household air pollution attributab...
# 3296    SDGAIRBODA  Ambient and household air pollution attributab...
# 3297    SDGAIRBODA  Ambient and household air pollution attributab...
# 3298    SDGAIRBODA  Ambient and household air pollution attributab...
#
#      ValueType ParentLocationCode ParentLocation Location type  \
# 3294   numeric                AFR         Africa       Country
# 3295   numeric                AMR       Americas       Country
# 3296   numeric                AFR         Africa       Country
# 3297   numeric                AMR       Americas       Country
# 3298   numeric                AMR       Americas       Country
#
#      SpatialDimValueCode             Location Period type  Period  ...  \
# 3294                 COM              Comoros        Year    2019  ...
# ...

# %%
del df['IndicatorCode']
del df['Indicator']
del df['ValueType']
del df['ParentLocationCode']
del df['Location type']

# %%
del df['Period type']
del df['IsLatestYear']
del df['Dim1 type']
del df['Dim3 type']
del df['FactValueUoM']
del df['FactValueNumericLowPrefix']
del df['FactValueNumericHighPrefix']
del df['FactValueTranslationID']
del df['FactComments']
del df['Language']
del df['DateModified']

# %%
del df['Dim3']
del df['Dim3ValueCode']
del df['DataSourceDimValueCode']
del df['DataSource']
del df['FactValueNumericPrefix']
del df['Dim2 type']
del df['Dim2ValueCode']
del df['SpatialDimValueCode']
del df['Dim1ValueCode']
df.head()
# Out:
#   ParentLocation Location  Period        Dim1  \
# 0         Africa  Comoros    2019      Female
# 1         Africa    Niger    2019      Female
# 2       Americas  Bahamas    2019      Female
# 3         Africa  Comoros    2019  Both sexes
# 4         Africa   Gambia    2019      Female
#
#                               Dim2  FactValueNumeric  FactValueNumericLow  \
# 0  Trachea, bronchus, lung cancers             0.000                0.000
# 1  Trachea, bronchus, lung cancers             0.024                0.020
# 2  Trachea, bronchus, lung cancers             0.046                0.000
# 3  Trachea, bronchus, lung cancers             0.065                0.053
# 4  Trachea, bronchus, lung cancers             0.068                0.058
#
#    FactValueNumericHigh                  Value
# 0                 0.000              0 [0 – 0]
# 1                 0.027   0.024 [0.02 – 0.027]
# 2                 0.140       0.046 [0 – 0.14]
# 3                 0.076  0.065 [0.053 – 0.076]
# ...

# %%
df=df.rename(columns= {'ParentLocation':'Continent', 'FactValueNumeric': 'Average Death Rate', 'Period': 'Year', 'Dim1':'Sex', 'FactValueNumericLow': 'Regional Low Deaths', 'FactValueNumericHigh': 'Regional High Deaths',
                      'Dim2': 'Cause of Death'})
df.head()
# Out:
#   Continent Location  Year         Sex                   Cause of Death  \
# 0    Africa  Comoros  2019      Female  Trachea, bronchus, lung cancers
# 1    Africa    Niger  2019      Female  Trachea, bronchus, lung cancers
# 2  Americas  Bahamas  2019      Female  Trachea, bronchus, lung cancers
# 3    Africa  Comoros  2019  Both sexes  Trachea, bronchus, lung cancers
# 4    Africa   Gambia  2019      Female  Trachea, bronchus, lung cancers
#
#    Average Death Rate  Regional Low Deaths  Regional High Deaths  \
# 0               0.000                0.000                 0.000
# 1               0.024                0.020                 0.027
# 2               0.046                0.000                 0.140
# 3               0.065                0.053                 0.076
# 4               0.068                0.058                 0.076
#
#                    Value
# 0              0 [0 – 0]
# 1   0.024 [0.02 – 0.027]
# 2       0.046 [0 – 0.14]
# 3  0.065 [0.053 – 0.076]
# ...
