# %%
import pandas as pd
from matplotlib import pyplot as plt
import requests
import json

# %%
file= "Resources/project1_data.csv"
df = pd.read_csv(file)
df.head()
# Out:
#   IndicatorCode                                          Indicator ValueType  \
# 0     SDGAIRBOD  Ambient and household air pollution attributab...   numeric
# 1     SDGAIRBOD  Ambient and household air pollution attributab...   numeric
# 2     SDGAIRBOD  Ambient and household air pollution attributab...   numeric
# 3     SDGAIRBOD  Ambient and household air pollution attributab...   numeric
# 4     SDGAIRBOD  Ambient and household air pollution attributab...   numeric
#
#   ParentLocationCode ParentLocation Location type SpatialDimValueCode  \
# 0                AFR         Africa       Country                 COM
# 1                AFR         Africa       Country                 NER
# 2                AMR       Americas       Country                 BHS
# 3                AFR         Africa       Country                 COM
# 4                AFR         Africa       Country                 GMB
#
#   Location Period type  Period  ...  FactValueUoM FactValueNumericLowPrefix  \
# 0  Comoros        Year    2019  ...           NaN                       NaN
# 1    Niger        Year    2019  ...           NaN                       NaN
# 2  Bahamas        Year    2019  ...           NaN                       NaN
# 3  Comoros        Year    2019  ...           NaN                       NaN
# 4   Gambia        Year    2019  ...           NaN                       NaN
#
#   FactValueNumericLow FactValueNumericHighPrefix FactValueNumericHigh  \
# 0               0.000                        NaN                0.000
# 1               0.020                        NaN                0.027
# 2               0.000                        NaN                0.140
# 3               0.053                        NaN                0.076
# 4               0.058                        NaN                0.076
#
#                    Value FactValueTranslationID  FactComments  Language  \
# 0              0 [0 – 0]                    NaN           NaN        EN
# 1   0.024 [0.02 – 0.027]                    NaN           NaN        EN
# 2       0.046 [0 – 0.14]                    NaN           NaN        EN
# 3  0.065 [0.053 – 0.076]                    NaN           NaN        EN
# 4  0.068 [0.058 – 0.076]                    NaN           NaN        EN
#
#                DateModified
# 0  2022-08-26T05:00:00.000Z
# 1  2022-08-26T05:00:00.000Z
# 2  2022-08-26T05:00:00.000Z
# 3  2022-08-26T05:00:00.000Z
# 4  2022-08-26T05:00:00.000Z
#
# [5 rows x 34 columns]

# %%
new_df =df[df['IndicatorCode'] == 'SDGAIRBODA']
new_df.head()
# Out:
#      IndicatorCode                                          Indicator  \
# 3294    SDGAIRBODA  Ambient and household air pollution attributab...
# 3295    SDGAIRBODA  Ambient and household air pollution attributab...
# 3296    SDGAIRBODA  Ambient and household air pollution attributab...
# 3297    SDGAIRBODA  Ambient and household air pollution attributab...
# 3298    SDGAIRBODA  Ambient and household air pollution attributab...
#
#      ValueType ParentLocationCode ParentLocation Location type  \
# 3294   numeric                AFR         Africa       Country
# 3295   numeric                AMR       Americas       Country
# 3296   numeric                AFR         Africa       Country
# 3297   numeric                AMR       Americas       Country
# 3298   numeric                AMR       Americas       Country
#
#      SpatialDimValueCode             Location Period type  Period  ...  \
# 3294                 COM              Comoros        Year    2019  ...
# 3295                 BHS              Bahamas        Year    2019  ...
# 3296                 NER                Niger        Year    2019  ...
# 3297                 BHS              Bahamas        Year    2019  ...
# 3298                 ATG  Antigua and Barbuda        Year    2019  ...
#
#       FactValueUoM FactValueNumericLowPrefix FactValueNumericLow  \
# 3294           NaN                       NaN               0.000
# 3295           NaN                       NaN               0.000
# 3296           NaN                       NaN               0.036
# 3297           NaN                       NaN               0.000
# 3298           NaN                       NaN               0.025
#
#      FactValueNumericHighPrefix FactValueNumericHigh                  Value  \
# 3294                        NaN                0.000              0 [0 – 0]
# 3295                        NaN                0.130       0.042 [0 – 0.13]
# 3296                        NaN                0.047  0.042 [0.036 – 0.047]
# 3297                        NaN                0.240       0.079 [0 – 0.24]
# 3298                        NaN                0.180   0.084 [0.025 – 0.18]
#
#      FactValueTranslationID  FactComments  Language              DateModified
# 3294                    NaN           NaN        EN  2022-08-26T05:00:00.000Z
# 3295                    NaN           NaN        EN  2022-08-26T05:00:00.000Z
# 3296                    NaN           NaN        EN  2022-08-26T05:00:00.000Z
# 3297                    NaN           NaN        EN  2022-08-26T05:00:00.000Z
# 3298                    NaN           NaN        EN  2022-08-26T05:00:00.000Z
#
# [5 rows x 34 columns]

# %%
del new_df['IndicatorCode']
del new_df['Indicator']
del new_df['ValueType']
del new_df['ParentLocationCode']
del new_df['Location type']

# %%
del new_df['Period type']
del new_df['IsLatestYear']
del new_df['Dim1 type']
del new_df['Dim3 type']
del new_df['FactValueUoM']
del new_df['FactValueNumericLowPrefix']
del new_df['FactValueNumericHighPrefix']
del new_df['FactValueTranslationID']
del new_df['FactComments']
del new_df['Language']
del new_df['DateModified']

# %%
del new_df['Dim3']
del new_df['Dim3ValueCode']
del new_df['DataSourceDimValueCode']
del new_df['DataSource']
del new_df['FactValueNumericPrefix']
del new_df['Dim2 type']
del new_df['Dim2ValueCode']

# %%
new_df=new_df.rename(columns= {'ParentLocation':'Region', 'SpatialDimValueCode':'Country Code', 'Period': 'Year', 'Dim1':'Sex', 'Dim1ValueCode': 'Sex Code',
                      'Dim2': 'Cause of Death', 'FactValueNumeric' : 'Average Deaths', 'FactValueNumericLow': 'Region Death Low', 'FactValueNumericHigh':'Region Death High'})
new_df
# Out:
#                      Region Country Code             Location  Year  \
# 3294                 Africa          COM              Comoros  2019
# 3295               Americas          BHS              Bahamas  2019
# 3296                 Africa          NER                Niger  2019
# 3297               Americas          BHS              Bahamas  2019
# 3298               Americas          ATG  Antigua and Barbuda  2019
# ...                     ...          ...                  ...   ...
# 6583  Eastern Mediterranean          SAU         Saudi Arabia  2019
# 6584                 Europe          ARM              Armenia  2019
# 6585                 Europe          UZB           Uzbekistan  2019
# 6586                 Africa          TGO                 Togo  2019
# 6587        Western Pacific          VUT              Vanuatu  2019
#
#              Sex Sex Code                   Cause of Death  Average Deaths  \
# 3294      Female     FMLE  Trachea, bronchus, lung cancers           0.000
# 3295      Female     FMLE  Trachea, bronchus, lung cancers           0.042
# 3296      Female     FMLE  Trachea, bronchus, lung cancers           0.042
# 3297  Both sexes     BTSX  Trachea, bronchus, lung cancers           0.079
# 3298      Female     FMLE  Trachea, bronchus, lung cancers           0.084
# ...          ...      ...                              ...             ...
# 6583        Male      MLE                            Total          98.320
# 6584        Male      MLE                            Total          98.350
# 6585      Female     FMLE          Ischaemic heart disease          98.470
# 6586        Male      MLE     Lower respiratory infections          99.400
# 6587      Female     FMLE          Ischaemic heart disease          99.770
#
#       Region Death Low  Region Death High                  Value
# 3294             0.000              0.000              0 [0 – 0]
# 3295             0.000              0.130       0.042 [0 – 0.13]
# 3296             0.036              0.047  0.042 [0.036 – 0.047]
# 3297             0.000              0.240       0.079 [0 – 0.24]
# 3298             0.025              0.180   0.084 [0.025 – 0.18]
# ...                ...                ...                    ...
# 6583            75.680            120.800  98.32 [75.68 – 120.8]
# 6584            70.600            126.600   98.35 [70.6 – 126.6]
# 6585            60.380            141.300  98.47 [60.38 – 141.3]
# 6586            83.280            113.500   99.4 [83.28 – 113.5]
# 6587            72.770            124.700  99.77 [72.77 – 124.7]
#
# [3294 rows x 11 columns]

# %%
# Which disease had the lowest death rate? Lowest Male? Lowest Female?
# Total deaths were

# %%
fem_tbl = new_df.loc[(new_df['Cause of Death'] == 'Trachea, bronchus, lung cancers') & (new_df['Sex'] == 'Female')]
fem_tbl
# Out:
#                Region Country Code                          Location  Year  \
# 3294           Africa          COM                           Comoros  2019
# 3295         Americas          BHS                           Bahamas  2019
# 3296           Africa          NER                             Niger  2019
# 3298         Americas          ATG               Antigua and Barbuda  2019
# 3306           Europe          FIN                           Finland  2019
# ...               ...          ...                               ...   ...
# 5764           Europe          SRB                            Serbia  2019
# 5804  Western Pacific          LAO  Lao People's Democratic Republic  2019
# 6049  Western Pacific          CHN                             China  2019
# 6187  South-East Asia          MMR                           Myanmar  2019
# 6361  Western Pacific          FSM  Micronesia (Federated States of)  2019
#
#          Sex Sex Code                   Cause of Death  Average Deaths  \
# 3294  Female     FMLE  Trachea, bronchus, lung cancers           0.000
# 3295  Female     FMLE  Trachea, bronchus, lung cancers           0.042
# 3296  Female     FMLE  Trachea, bronchus, lung cancers           0.042
# 3298  Female     FMLE  Trachea, bronchus, lung cancers           0.084
# 3306  Female     FMLE  Trachea, bronchus, lung cancers           0.140
# ...      ...      ...                              ...             ...
# 5764  Female     FMLE  Trachea, bronchus, lung cancers           5.290
# 5804  Female     FMLE  Trachea, bronchus, lung cancers           5.740
# 6049  Female     FMLE  Trachea, bronchus, lung cancers           6.700
# 6187  Female     FMLE  Trachea, bronchus, lung cancers           7.050
# 6361  Female     FMLE  Trachea, bronchus, lung cancers           8.130
#
#       Region Death Low  Region Death High                  Value
# 3294             0.000              0.000              0 [0 – 0]
# 3295             0.000              0.130       0.042 [0 – 0.13]
# 3296             0.036              0.047  0.042 [0.036 – 0.047]
# 3298             0.025              0.180   0.084 [0.025 – 0.18]
# 3306             0.056              0.290    0.14 [0.056 – 0.29]
# ...                ...                ...                    ...
# 5764             3.280              7.870     5.29 [3.28 – 7.87]
# 5804             4.620              6.780     5.74 [4.62 – 6.78]
# 6049             4.190              9.450      6.7 [4.19 – 9.45]
# 6187             5.660              8.290     7.05 [5.66 – 8.29]
# 6361             6.210              9.760     8.13 [6.21 – 9.76]
#
# [183 rows x 11 columns]

# %%
totals = new_df.groupby(['Cause of Death', 'Sex']).agg({'Average Deaths':['sum']})
totals
# Out:
#                                                  Average Deaths
#                                                             sum
# Cause of Death                        Sex
# Chronic obstructive pulmonary disease Both sexes       1796.860
#                                       Female           1376.150
#                                       Male             2369.970
# Ischaemic heart disease               Both sexes       7640.380
#                                       Female           6458.740
#                                       Male             9006.560
# Lower respiratory infections          Both sexes       4058.560
#                                       Female           3441.160
#                                       Male             4830.570
# Stroke                                Both sexes       4479.900
#                                       Female           4276.670
#                                       Male             4722.760
# Total                                 Both sexes      18440.490
#                                       Female          15838.090
#                                       Male            21620.900
# Trachea, bronchus, lung cancers       Both sexes        464.749
#                                       Female            285.348
#                                       Male              690.310

# %%
male_totals = totals[totals['Cause of Death']['Sex'] == 'Male']
male_totals
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Cause of Death'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /Users/megphilippsen/Desktop/project_1/Tim_Project_1.ipynb Cell 11 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/megphilippsen/Desktop/project_1/Tim_Project_1.ipynb#X50sZmlsZQ%3D%3D?line=0'>1</a> male_totals = totals[totals['Cause of Death']['Sex'] == 'Male']
#       <a href='vscode-notebook-cell:/Users/megphilippsen/Desktop/project_1/Tim_Project_1.ipynb#X50sZmlsZQ%3D%3D?line=1'>2</a> male_totals
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:3504, in DataFrame.__getitem__(self, key)
#    3502 if is_single_key:
#    3503     if self.columns.nlevels > 1:
# -> 3504         return self._getitem_multilevel(key)
#    3505     indexer = self.columns.get_loc(key)
#    3506     if is_integer(indexer):
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:3555, in DataFrame._getitem_multilevel(self, key)
#    3553 def _getitem_multilevel(self, key):
#    3554     # self.columns is a MultiIndex
# -> 3555     loc = self.columns.get_loc(key)
#    3556     if isinstance(loc, (slice, np.ndarray)):
#    3557         new_columns = self.columns[loc]
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/multi.py:2869, in MultiIndex.get_loc(self, key, method)
#    2866     return mask
#    2868 if not isinstance(key, tuple):
# -> 2869     loc = self._get_level_indexer(key, level=0)
#    2870     return _maybe_to_slice(loc)
#    2872 keylen = len(key)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/multi.py:3222, in MultiIndex._get_level_indexer(self, key, level, indexer)
#    3218         return slice(i, j, step)
#    3220 else:
# -> 3222     idx = self._get_loc_single_level_index(level_index, key)
#    3224     if level > 0 or self._lexsort_depth == 0:
#    3225         # Desired level is not sorted
#    3226         if isinstance(idx, slice):
#    3227             # test_get_loc_partial_timestamp_multiindex
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/multi.py:2802, in MultiIndex._get_loc_single_level_index(self, level_index, key)
#    2800     return -1
#    2801 else:
# -> 2802     return level_index.get_loc(key)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'Cause of Death'

# %%
female_disease = [1376.15, 6458.74, 3441.16, 4276.67, 285.348]
male_disease = [2369.97, 9006.56, 4830.57, 4722.76, 690.31]
both_sex_disease = [1796.86, 7640.38, 4058.56, 4479.9, 464.749]
index_disease = ['Chronic Obstructive \n Pulminary Disease', 'Ischaemic \n Heart Disease', 'Lower Respiratory \n Infections', 'Stroke', 'Trachea, Bronchus, \n Lung Cancers']
disease_fig_df = pd.DataFrame({'Female': female_disease, 'Male': male_disease, 'Both Sexes': both_sex_disease}, index = index_disease )

disease_fig_df


disease_fig_df.plot(kind='bar')
plt.title('Average Air Pollution Deaths By Disease and Gender')
plt.xlabel('Disease')
plt.ylabel('Average Deaths')
plt.show()

# %%
cause_death = totals['Cause of Death']
gender = totals['Sex']
deaths = totals['Average Deaths']

females = plt.plot(cause_death, deaths, color="blue", label="World Average" )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Cause of Death'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /Users/megphilippsen/Desktop/project_1/Tim_Project_1.ipynb Cell 11 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/megphilippsen/Desktop/project_1/Tim_Project_1.ipynb#X45sZmlsZQ%3D%3D?line=0'>1</a> cause_death = totals['Cause of Death']
#       <a href='vscode-notebook-cell:/Users/megphilippsen/Desktop/project_1/Tim_Project_1.ipynb#X45sZmlsZQ%3D%3D?line=1'>2</a> gender = totals['Sex']
#       <a href='vscode-notebook-cell:/Users/megphilippsen/Desktop/project_1/Tim_Project_1.ipynb#X45sZmlsZQ%3D%3D?line=2'>3</a> deaths = totals['Average Deaths']
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:3504, in DataFrame.__getitem__(self, key)
#    3502 if is_single_key:
#    3503     if self.columns.nlevels > 1:
# -> 3504         return self._getitem_multilevel(key)
#    3505     indexer = self.columns.get_loc(key)
#    3506     if is_integer(indexer):
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:3555, in DataFrame._getitem_multilevel(self, key)
#    3553 def _getitem_multilevel(self, key):
#    3554     # self.columns is a MultiIndex
# -> 3555     loc = self.columns.get_loc(key)
#    3556     if isinstance(loc, (slice, np.ndarray)):
#    3557         new_columns = self.columns[loc]
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/multi.py:2869, in MultiIndex.get_loc(self, key, method)
#    2866     return mask
#    2868 if not isinstance(key, tuple):
# -> 2869     loc = self._get_level_indexer(key, level=0)
#    2870     return _maybe_to_slice(loc)
#    2872 keylen = len(key)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/multi.py:3222, in MultiIndex._get_level_indexer(self, key, level, indexer)
#    3218         return slice(i, j, step)
#    3220 else:
# -> 3222     idx = self._get_loc_single_level_index(level_index, key)
#    3224     if level > 0 or self._lexsort_depth == 0:
#    3225         # Desired level is not sorted
#    3226         if isinstance(idx, slice):
#    3227             # test_get_loc_partial_timestamp_multiindex
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/multi.py:2802, in MultiIndex._get_loc_single_level_index(self, level_index, key)
#    2800     return -1
#    2801 else:
# -> 2802     return level_index.get_loc(key)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'Cause of Death'

# %%
totals.plot(kind= 'bar')
# Out:
# <AxesSubplot:xlabel='Cause of Death,Sex'>

# %%
# Find Total Average Deaths

avg_deaths = new_df.loc[new_df['Cause of Death'] == 'Total']
total_avg_deaths = avg_deaths.sum()['Average Deaths']
total_avg_deaths
# Out:
# 55899.47999999998

# %%
# Total Avg deaths - Male

male_deaths = new_df.loc[(new_df['Cause of Death'] == 'Total') & (new_df['Sex'] == 'Male')]
total_avg_male_deaths = male_deaths.sum()['Average Deaths']

total_avg_male_deaths
# Out:
# 21620.9

# %%
# Total Avg deaths - Female
avg_female_deaths = new_df.loc[(new_df['Cause of Death'] == 'Total') & (new_df['Sex'] == 'Female')]
total_avg_female_deaths = avg_female_deaths.sum()['Average Deaths']
total_avg_female_deaths
# Out:
# 15838.089999999997

# %%
# Find total average deaths by trachea, bronchus, lung cancer

avg_trachea_deaths = new_df.loc[new_df['Cause of Death'] == 'Trachea, bronchus, lung cancers']
total_avg_trachea_deaths = avg_trachea_deaths.sum()['Average Deaths']
total_avg_trachea_deaths
# Out:
# 1440.4070000000004

# %%
# Find total average deaths by trachea, bronchus, lung cancer - Male

avg_male_trachea_deaths = new_df.loc[(new_df['Cause of Death'] == 'Trachea, bronchus, lung cancers') & (new_df['Sex'] == 'Male')]
total_avg_male_trachea_deaths = avg_male_trachea_deaths.sum()['Average Deaths']
total_avg_male_trachea_deaths
# Out:
# 690.3099999999997

# %%
# Find total average deaths by trachea, bronchus, lung cancer - Female

avg_female_trachea_deaths = new_df.loc[(new_df['Cause of Death'] == 'Trachea, bronchus, lung cancers') & (new_df['Sex'] == 'Female')]
total_avg_female_trachea_deaths = avg_female_trachea_deaths.sum()['Average Deaths']
total_avg_female_trachea_deaths
# Out:
# 285.34799999999996

# %%
# Find total average deaths by COPD

avg_copd_deaths = new_df.loc[new_df['Cause of Death'] == 'Chronic obstructive pulmonary disease']
total_avg_copd_deaths = avg_copd_deaths.sum()['Average Deaths']
total_avg_copd_deaths
# Out:
# 5542.980000000001

# %%
# Find total average deaths by COPD - Male

avg_male_copd_deaths = new_df.loc[(new_df['Cause of Death'] == 'Chronic obstructive pulmonary disease') & (new_df['Sex'] == 'Male')]
total_avg_male_copd_deaths = avg_male_copd_deaths.sum()['Average Deaths']
total_avg_male_copd_deaths
# Out:
# 2369.9700000000007

# %%
# Find total average deaths by COPD - Female

avg_female_copd_deaths = new_df.loc[(new_df['Cause of Death'] == 'Chronic obstructive pulmonary disease') & (new_df['Sex'] == 'Female')]
total_avg_female_copd_deaths = avg_female_copd_deaths.sum()['Average Deaths']
total_avg_female_copd_deaths
# Out:
# 1376.1499999999999

# %%
# Find total average deaths by lower respiratory infection

avg_lri_deaths = new_df.loc[new_df['Cause of Death'] == 'Lower respiratory infections']
total_avg_lri_deaths =avg_lri_deaths.sum()['Average Deaths']
total_avg_lri_deaths
# Out:
# 12330.290000000006

# %%
# Find total average deaths by lower respiratory infection - Male

avg_male_lri_deaths = new_df.loc[(new_df['Cause of Death'] == 'Lower respiratory infections') & (new_df['Sex'] == 'Male')]
total_avg_male_lri_deaths = avg_male_lri_deaths.sum()['Average Deaths']
total_avg_male_lri_deaths
# Out:
# 4830.570000000002

# %%
# Find total average deaths by lower respiratory infection - Female

avg_female_lri_deaths = new_df.loc[(new_df['Cause of Death'] == 'Lower respiratory infections') & (new_df['Sex'] =='Female')]
total_avg_female_lri_deaths = avg_female_lri_deaths.sum()['Average Deaths']
total_avg_female_lri_deaths
# Out:
# 3441.160000000001

# %%
# Find total average deaths by ischaemic heart disease

avg_ihd_deaths = new_df.loc[new_df['Cause of Death'] == 'Ischaemic heart disease']
total_avg_ihd_deaths = avg_ihd_deaths.sum()['Average Deaths']
total_avg_ihd_deaths
# Out:
# 23105.680000000004

# %%
# Find total average deaths by ischaemic heart disease - Male

avg_male_ihd_deaths = new_df.loc[(new_df['Cause of Death'] == 'Ischaemic heart disease') & (new_df['Sex'] == 'Male')]
total_avg_male_ihd_deaths = avg_male_ihd_deaths.sum()['Average Deaths']
total_avg_male_ihd_deaths
# Out:
# 9006.559999999994

# %%
# Find total average deaths by ischaemic heart disease - Female

avg_female_ihd_deaths = new_df.loc[(new_df['Cause of Death'] == 'Ischaemic heart disease') & (new_df['Sex'] == 'Female')] 
total_avg_female_ihd_deaths = avg_female_ihd_deaths.sum()['Average Deaths']
total_avg_female_ihd_deaths
# Out:
# 6458.740000000003

# %%
# Find total average deaths by stroke

avg_stroke_deaths = new_df.loc[new_df['Cause of Death'] == 'Stroke']
total_avg_stroke_deaths = avg_stroke_deaths.sum()['Average Deaths']
total_avg_stroke_deaths
# Out:
# 13479.329999999996

# %%
# Find total average deaths by stroke

avg_male_stroke_deaths = new_df.loc[(new_df['Cause of Death'] == 'Stroke') & (new_df['Sex'] == 'Male')]
total_avg_male_stroke_deaths = avg_male_stroke_deaths.sum()['Average Deaths']
total_avg_male_stroke_deaths
# Out:
# 4722.760000000004

# %%
# Find total average deaths by stroke

avg_female_stroke_deaths = new_df.loc[(new_df['Cause of Death'] == 'Stroke') & (new_df['Sex'] == 'Female')]
total_avg_female_stroke_deaths = avg_female_stroke_deaths.sum()['Average Deaths']
total_avg_female_stroke_deaths
# Out:
# 4276.670000000002

# %%
total_deaths_by_disease = pd.DataFrame({'Total Average Death by Trachea, Bronchus, Lung Cancers' : [total_avg_trachea_deaths],
                                        'Total Average Death by Trachea, Bronchus, Lung Cancers - Male': [total_avg_male_trachea_deaths],
                                        'Total Average Death by Trachea, Bronchus, Lung Cancers - Female': [total_avg_female_trachea_deaths],
                                        'Total Average Death by Chronic obstructive pulmonary disease': [total_avg_copd_deaths] ,
                                        'Total Average Death by Chronic obstructive pulmonary disease - Male':[total_avg_male_copd_deaths],
                                        'Total Average Death by Chronic obstructive pulmonary disease - Female': [total_avg_female_copd_deaths],
                                        'Total Average Death by Lower respiratory infections': [total_avg_lri_deaths] ,
                                        'Total Average Death by Lower respiratory infections - Male':[total_avg_male_lri_deaths] ,
                                        'Total Average Death by Lower respiratory infections - Female':[total_avg_female_lri_deaths] ,
                                        'Total Average Death by Ischaemic heart disease': [total_avg_ihd_deaths] ,
                                        'Total Average Death by Ischaemic heart disease - Male':[total_avg_male_ihd_deaths],
                                        'Total Average Death by Ischaemic heart disease - Female':[total_avg_female_ihd_deaths],
                                        'Total Average Death by Stroke': [total_avg_stroke_deaths] ,
                                        'Total Average Death by Stroke - Male': [total_avg_male_stroke_deaths],
                                        'Total Average Death by Stroke - Female':[total_avg_female_stroke_deaths],})

total_deaths_by_disease
# Out:
#    Total Average Death by Trachea, Bronchus, Lung Cancers  \
# 0                                           1440.407
#
#    Total Average Death by Trachea, Bronchus, Lung Cancers - Male  \
# 0                                             690.31
#
#    Total Average Death by Trachea, Bronchus, Lung Cancers - Female  \
# 0                                            285.348
#
#    Total Average Death by Chronic obstructive pulmonary disease  \
# 0                                            5542.98
#
#    Total Average Death by Chronic obstructive pulmonary disease - Male  \
# 0                                            2369.97
#
#    Total Average Death by Chronic obstructive pulmonary disease - Female  \
# 0                                            1376.15
#
#    Total Average Death by Lower respiratory infections  \
# 0                                           12330.29
#
#    Total Average Death by Lower respiratory infections - Male  \
# 0                                            4830.57
#
#    Total Average Death by Lower respiratory infections - Female  \
# 0                                            3441.16
#
#    Total Average Death by Ischaemic heart disease  \
# 0                                        23105.68
#
#    Total Average Death by Ischaemic heart disease - Male  \
# 0                                            9006.56
#
#    Total Average Death by Ischaemic heart disease - Female  \
# 0                                            6458.74
#
#    Total Average Death by Stroke  Total Average Death by Stroke - Male  \
# 0                       13479.33                               4722.76
#
#    Total Average Death by Stroke - Female
# 0                                 4276.67
